# %%
import json
import pickle
import numpy as np

# %%
with open('results/test.json', 'r') as f:
    results = json.load(f)

# %%
results.keys()
# Out:
# dict_keys(['results'])

# %%
len(results['results'])
# Out:
# 327

# %%
results['results']
# Out:
# [[{'label': 1, 'score': 0.7598347067832947, 'gt': 1},
#   {'label': 0, 'score': 0.24016530811786652, 'gt': 1}],
#  [{'label': 1, 'score': 0.9903556108474731, 'gt': 1},
#   {'label': 0, 'score': 0.009644348174333572, 'gt': 1}],
#  [{'label': 1, 'score': 0.9917163252830505, 'gt': 1},
#   {'label': 0, 'score': 0.008283721283078194, 'gt': 1}],
#  [{'label': 1, 'score': 0.8602752089500427, 'gt': 1},
#   {'label': 0, 'score': 0.13972482085227966, 'gt': 1}],
#  [{'label': 1, 'score': 0.9971287846565247, 'gt': 1},
#   {'label': 0, 'score': 0.002871245611459017, 'gt': 1}],
#  [{'label': 1, 'score': 0.7718603610992432, 'gt': 1},
#   {'label': 0, 'score': 0.22813959419727325, 'gt': 1}],
#  [{'label': 1, 'score': 0.9891452193260193, 'gt': 0},
#   {'label': 0, 'score': 0.010854867286980152, 'gt': 0}],
#  [{'label': 1, 'score': 0.9989651441574097, 'gt': 0},
#   {'label': 0, 'score': 0.001034816144965589, 'gt': 0}],
#  [{'label': 0, 'score': 0.5426390171051025, 'gt': 0},
#   {'label': 1, 'score': 0.45736101269721985, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999865293502808, 'gt': 1},
#   {'label': 0, 'score': 1.345533109997632e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.9772565364837646, 'gt': 1},
#   {'label': 1, 'score': 0.022743409499526024, 'gt': 1}],
#  [{'label': 0, 'score': 0.8124637603759766, 'gt': 1},
#   {'label': 1, 'score': 0.18753620982170105, 'gt': 1}],
#  [{'label': 1, 'score': 0.8537489771842957, 'gt': 1},
#   {'label': 0, 'score': 0.14625100791454315, 'gt': 1}],
#  [{'label': 1, 'score': 0.8631922006607056, 'gt': 1},
#   {'label': 0, 'score': 0.13680776953697205, 'gt': 1}],
#  [{'label': 1, 'score': 0.7684928178787231, 'gt': 1},
#   {'label': 0, 'score': 0.23150719702243805, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 4.023266230801861e-14, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999909400939941, 'gt': 1},
#   {'label': 0, 'score': 9.090438652492594e-06, 'gt': 1}],
#  [{'label': 0, 'score': 0.9856416583061218, 'gt': 1},
#   {'label': 1, 'score': 0.014358332380652428, 'gt': 1}],
#  [{'label': 0, 'score': 0.9962688684463501, 'gt': 1},
#   {'label': 1, 'score': 0.0037311140913516283, 'gt': 1}],
#  [{'label': 0, 'score': 0.9167119264602661, 'gt': 0},
#   {'label': 1, 'score': 0.08328810334205627, 'gt': 0}],
#  [{'label': 0, 'score': 0.9867313504219055, 'gt': 0},
#   {'label': 1, 'score': 0.013268649578094482, 'gt': 0}],
#  [{'label': 1, 'score': 0.8913211226463318, 'gt': 0},
#   {'label': 0, 'score': 0.1086788922548294, 'gt': 0}],
#  [{'label': 0, 'score': 0.9996531009674072, 'gt': 0},
#   {'label': 1, 'score': 0.00034684661659412086, 'gt': 0}],
#  [{'label': 0, 'score': 0.8942470550537109, 'gt': 1},
#   {'label': 1, 'score': 0.10575295239686966, 'gt': 1}],
#  [{'label': 0, 'score': 0.9906796813011169, 'gt': 1},
#   {'label': 1, 'score': 0.009320363402366638, 'gt': 1}],
#  [{'label': 1, 'score': 0.9969115853309631, 'gt': 0},
#   {'label': 0, 'score': 0.0030883951112627983, 'gt': 0}],
#  [{'label': 1, 'score': 0.9429982900619507, 'gt': 0},
#   {'label': 0, 'score': 0.057001784443855286, 'gt': 0}],
#  [{'label': 1, 'score': 0.9997043013572693, 'gt': 1},
#   {'label': 0, 'score': 0.0002956584212370217, 'gt': 1}],
#  [{'label': 0, 'score': 0.8001584410667419, 'gt': 1},
#   {'label': 1, 'score': 0.19984163343906403, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999995231628418, 'gt': 1},
#   {'label': 0, 'score': 4.891254548056168e-07, 'gt': 1}],
#  [{'label': 0, 'score': 0.9996284246444702, 'gt': 0},
#   {'label': 1, 'score': 0.0003716110368259251, 'gt': 0}],
#  [{'label': 1, 'score': 0.9723261594772339, 'gt': 0},
#   {'label': 0, 'score': 0.02767384983599186, 'gt': 0}],
#  [{'label': 0, 'score': 0.9856821894645691, 'gt': 0},
#   {'label': 1, 'score': 0.014317736029624939, 'gt': 0}],
#  [{'label': 1, 'score': 0.5161311030387878, 'gt': 0},
#   {'label': 0, 'score': 0.4838688373565674, 'gt': 0}],
#  [{'label': 0, 'score': 0.878380298614502, 'gt': 1},
#   {'label': 1, 'score': 0.12161971628665924, 'gt': 1}],
#  [{'label': 0, 'score': 0.9998496770858765, 'gt': 1},
#   {'label': 1, 'score': 0.00015028483176138252, 'gt': 1}],
#  [{'label': 0, 'score': 0.9973159432411194, 'gt': 0},
#   {'label': 1, 'score': 0.002684042090550065, 'gt': 0}],
#  [{'label': 1, 'score': 0.9728432893753052, 'gt': 0},
#   {'label': 0, 'score': 0.027156643569469452, 'gt': 0}],
#  [{'label': 1, 'score': 0.9990204572677612, 'gt': 1},
#   {'label': 0, 'score': 0.0009795771911740303, 'gt': 1}],
#  [{'label': 0, 'score': 0.9958755373954773, 'gt': 1},
#   {'label': 1, 'score': 0.004124443978071213, 'gt': 1}],
#  [{'label': 1, 'score': 0.9980489015579224, 'gt': 1},
#   {'label': 0, 'score': 0.001951048499904573, 'gt': 1}],
#  [{'label': 0, 'score': 0.6760696768760681, 'gt': 1},
#   {'label': 1, 'score': 0.3239302933216095, 'gt': 1}],
#  [{'label': 0, 'score': 0.9681337475776672, 'gt': 0},
#   {'label': 1, 'score': 0.03186628594994545, 'gt': 0}],
#  [{'label': 0, 'score': 0.974049985408783, 'gt': 0},
#   {'label': 1, 'score': 0.02595001831650734, 'gt': 0}],
#  [{'label': 1, 'score': 0.8772707581520081, 'gt': 0},
#   {'label': 0, 'score': 0.12272924184799194, 'gt': 0}],
#  [{'label': 0, 'score': 0.887238085269928, 'gt': 1},
#   {'label': 1, 'score': 0.11276190727949142, 'gt': 1}],
#  [{'label': 1, 'score': 0.9969319105148315, 'gt': 0},
#   {'label': 0, 'score': 0.003068042453378439, 'gt': 0}],
#  [{'label': 1, 'score': 0.960793673992157, 'gt': 0},
#   {'label': 0, 'score': 0.03920627385377884, 'gt': 0}],
#  [{'label': 0, 'score': 0.9796791076660156, 'gt': 0},
#   {'label': 1, 'score': 0.0203209538012743, 'gt': 0}],
#  [{'label': 0, 'score': 0.9643116593360901, 'gt': 1},
#   {'label': 1, 'score': 0.035688288509845734, 'gt': 1}],
#  [{'label': 0, 'score': 0.9918305277824402, 'gt': 1},
#   {'label': 1, 'score': 0.008169475011527538, 'gt': 1}],
#  [{'label': 0, 'score': 0.9900845289230347, 'gt': 1},
#   {'label': 1, 'score': 0.009915485978126526, 'gt': 1}],
#  [{'label': 0, 'score': 0.9805938601493835, 'gt': 1},
#   {'label': 1, 'score': 0.019406141713261604, 'gt': 1}],
#  [{'label': 1, 'score': 0.9708840250968933, 'gt': 1},
#   {'label': 0, 'score': 0.029115939512848854, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 7.335909102401672e-10, 'gt': 1}],
#  [{'label': 1, 'score': 0.971325159072876, 'gt': 1},
#   {'label': 0, 'score': 0.028674820438027382, 'gt': 1}],
#  [{'label': 1, 'score': 0.642960786819458, 'gt': 0},
#   {'label': 0, 'score': 0.3570391535758972, 'gt': 0}],
#  [{'label': 1, 'score': 0.999653697013855, 'gt': 0},
#   {'label': 0, 'score': 0.00034632228198461235, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999784231185913, 'gt': 1},
#   {'label': 0, 'score': 2.1542926333495416e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999983310699463, 'gt': 1},
#   {'label': 0, 'score': 1.6822754105305648e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.6738788485527039, 'gt': 1},
#   {'label': 0, 'score': 0.3261212110519409, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999979734420776, 'gt': 1},
#   {'label': 0, 'score': 2.0359293557703495e-06, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 6.461731594242792e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.6608725786209106, 'gt': 1},
#   {'label': 0, 'score': 0.33912745118141174, 'gt': 1}],
#  [{'label': 1, 'score': 0.9996531009674072, 'gt': 1},
#   {'label': 0, 'score': 0.0003469508374109864, 'gt': 1}],
#  [{'label': 0, 'score': 0.6738066673278809, 'gt': 0},
#   {'label': 1, 'score': 0.32619333267211914, 'gt': 0}],
#  [{'label': 1, 'score': 0.9968339800834656, 'gt': 1},
#   {'label': 0, 'score': 0.0031660632230341434, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 3.700766981751258e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999275207519531, 'gt': 1},
#   {'label': 0, 'score': 7.248415204230696e-05, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.0512576862698855e-16, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 7.54533449609518e-11, 'gt': 1}],
#  [{'label': 1, 'score': 0.9990076422691345, 'gt': 1},
#   {'label': 0, 'score': 0.000992343993857503, 'gt': 1}],
#  [{'label': 1, 'score': 0.9996403455734253, 'gt': 1},
#   {'label': 0, 'score': 0.00035967439180240035, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999561309814453, 'gt': 1},
#   {'label': 0, 'score': 4.38532697444316e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999363422393799, 'gt': 1},
#   {'label': 0, 'score': 6.36265249340795e-05, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 2.6314541656802248e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998799562454224, 'gt': 1},
#   {'label': 0, 'score': 0.00012002975563518703, 'gt': 1}],
#  [{'label': 1, 'score': 0.999996542930603, 'gt': 1},
#   {'label': 0, 'score': 3.4721601878118236e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9937387704849243, 'gt': 1},
#   {'label': 0, 'score': 0.006261241622269154, 'gt': 1}],
#  [{'label': 1, 'score': 0.9966418743133545, 'gt': 1},
#   {'label': 0, 'score': 0.003358116140589118, 'gt': 1}],
#  [{'label': 0, 'score': 0.7720808386802673, 'gt': 0},
#   {'label': 1, 'score': 0.22791919112205505, 'gt': 0}],
#  [{'label': 1, 'score': 0.934894859790802, 'gt': 0},
#   {'label': 0, 'score': 0.06510507315397263, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999939203262329, 'gt': 1},
#   {'label': 0, 'score': 6.106735781941097e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.8538885712623596, 'gt': 1},
#   {'label': 0, 'score': 0.14611147344112396, 'gt': 1}],
#  [{'label': 0, 'score': 0.6072792410850525, 'gt': 1},
#   {'label': 1, 'score': 0.3927207589149475, 'gt': 1}],
#  [{'label': 1, 'score': 0.9931766986846924, 'gt': 1},
#   {'label': 0, 'score': 0.006823324598371983, 'gt': 1}],
#  [{'label': 1, 'score': 0.972421407699585, 'gt': 0},
#   {'label': 0, 'score': 0.027578560635447502, 'gt': 0}],
#  [{'label': 0, 'score': 0.5979412794113159, 'gt': 0},
#   {'label': 1, 'score': 0.4020586907863617, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999759197235107, 'gt': 0},
#   {'label': 0, 'score': 2.4045788450166583e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999990463256836, 'gt': 1},
#   {'label': 0, 'score': 9.224316386280407e-07, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999487400054932, 'gt': 1},
#   {'label': 0, 'score': 5.1297800382599235e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9993042945861816, 'gt': 1},
#   {'label': 0, 'score': 0.0006957362056709826, 'gt': 1}],
#  [{'label': 1, 'score': 0.9045221209526062, 'gt': 1},
#   {'label': 0, 'score': 0.09547784179449081, 'gt': 1}],
#  [{'label': 1, 'score': 0.9886981248855591, 'gt': 1},
#   {'label': 0, 'score': 0.011301864869892597, 'gt': 1}],
#  [{'label': 1, 'score': 0.9881672263145447, 'gt': 0},
#   {'label': 0, 'score': 0.011832724325358868, 'gt': 0}],
#  [{'label': 1, 'score': 0.999697208404541, 'gt': 1},
#   {'label': 0, 'score': 0.0003028197679668665, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999974966049194, 'gt': 1},
#   {'label': 0, 'score': 2.5108611225732602e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999858140945435, 'gt': 1},
#   {'label': 0, 'score': 1.4170806934998836e-05, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 3.4191509623582306e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999918937683105, 'gt': 1},
#   {'label': 0, 'score': 8.165512554114684e-06, 'gt': 1}],
#  [{'label': 0, 'score': 0.974860668182373, 'gt': 1},
#   {'label': 1, 'score': 0.02513935975730419, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999206066131592, 'gt': 1},
#   {'label': 0, 'score': 7.936786278150976e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.7534704208374023, 'gt': 0},
#   {'label': 1, 'score': 0.2465295046567917, 'gt': 0}],
#  [{'label': 1, 'score': 0.9998019337654114, 'gt': 1},
#   {'label': 0, 'score': 0.00019804667681455612, 'gt': 1}],
#  [{'label': 1, 'score': 0.9230917096138, 'gt': 1},
#   {'label': 0, 'score': 0.07690831273794174, 'gt': 1}],
#  [{'label': 1, 'score': 0.9919022917747498, 'gt': 1},
#   {'label': 0, 'score': 0.008097685873508453, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998955726623535, 'gt': 1},
#   {'label': 0, 'score': 0.00010435910371597856, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997873902320862, 'gt': 1},
#   {'label': 0, 'score': 0.0002125757746398449, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 3.5234497541836163e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.9815180897712708, 'gt': 1},
#   {'label': 0, 'score': 0.018481949344277382, 'gt': 1}],
#  [{'label': 0, 'score': 0.9843371510505676, 'gt': 1},
#   {'label': 1, 'score': 0.01566288433969021, 'gt': 1}],
#  [{'label': 0, 'score': 0.9997387528419495, 'gt': 0},
#   {'label': 1, 'score': 0.00026124485884793103, 'gt': 0}],
#  [{'label': 0, 'score': 0.5697256326675415, 'gt': 1},
#   {'label': 1, 'score': 0.43027442693710327, 'gt': 1}],
#  [{'label': 0, 'score': 0.9986996650695801, 'gt': 1},
#   {'label': 1, 'score': 0.001300264266319573, 'gt': 1}],
#  [{'label': 1, 'score': 0.9982337951660156, 'gt': 0},
#   {'label': 0, 'score': 0.0017661552410572767, 'gt': 0}],
#  [{'label': 1, 'score': 0.9741611480712891, 'gt': 0},
#   {'label': 0, 'score': 0.02583887055516243, 'gt': 0}],
#  [{'label': 0, 'score': 0.9736377596855164, 'gt': 0},
#   {'label': 1, 'score': 0.026362279430031776, 'gt': 0}],
#  [{'label': 0, 'score': 0.9485602974891663, 'gt': 1},
#   {'label': 1, 'score': 0.05143967643380165, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999997615814209, 'gt': 1},
#   {'label': 0, 'score': 2.976482278427284e-07, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999713897705078, 'gt': 1},
#   {'label': 0, 'score': 2.8632039175136015e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.7930725812911987, 'gt': 1},
#   {'label': 0, 'score': 0.2069273591041565, 'gt': 1}],
#  [{'label': 0, 'score': 0.9769371747970581, 'gt': 0},
#   {'label': 1, 'score': 0.02306278608739376, 'gt': 0}],
#  [{'label': 1, 'score': 0.8796060681343079, 'gt': 0},
#   {'label': 0, 'score': 0.12039387226104736, 'gt': 0}],
#  [{'label': 1, 'score': 0.9285330176353455, 'gt': 1},
#   {'label': 0, 'score': 0.07146690785884857, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999876022338867, 'gt': 1},
#   {'label': 0, 'score': 1.2414728189469315e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999895095825195, 'gt': 1},
#   {'label': 0, 'score': 1.0519325769564603e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.9994975328445435, 'gt': 0},
#   {'label': 1, 'score': 0.0005024702986702323, 'gt': 0}],
#  [{'label': 1, 'score': 0.9846704006195068, 'gt': 0},
#   {'label': 0, 'score': 0.015329658053815365, 'gt': 0}],
#  [{'label': 1, 'score': 0.9950307607650757, 'gt': 1},
#   {'label': 0, 'score': 0.0049691651947796345, 'gt': 1}],
#  [{'label': 1, 'score': 0.9494287967681885, 'gt': 1},
#   {'label': 0, 'score': 0.05057121440768242, 'gt': 1}],
#  [{'label': 1, 'score': 0.6765644550323486, 'gt': 0},
#   {'label': 0, 'score': 0.32343554496765137, 'gt': 0}],
#  [{'label': 0, 'score': 0.888020932674408, 'gt': 0},
#   {'label': 1, 'score': 0.11197903007268906, 'gt': 0}],
#  [{'label': 0, 'score': 0.9970605969429016, 'gt': 0},
#   {'label': 1, 'score': 0.0029393588192760944, 'gt': 0}],
#  [{'label': 0, 'score': 0.9825055599212646, 'gt': 1},
#   {'label': 1, 'score': 0.017494479194283485, 'gt': 1}],
#  [{'label': 1, 'score': 0.9748077988624573, 'gt': 1},
#   {'label': 0, 'score': 0.02519218623638153, 'gt': 1}],
#  [{'label': 1, 'score': 0.9491987228393555, 'gt': 1},
#   {'label': 0, 'score': 0.0508013553917408, 'gt': 1}],
#  [{'label': 1, 'score': 0.9160085916519165, 'gt': 1},
#   {'label': 0, 'score': 0.08399141579866409, 'gt': 1}],
#  [{'label': 0, 'score': 0.9095902442932129, 'gt': 1},
#   {'label': 1, 'score': 0.0904097706079483, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.802760074554044e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9379329681396484, 'gt': 1},
#   {'label': 0, 'score': 0.06206706911325455, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999992847442627, 'gt': 1},
#   {'label': 0, 'score': 7.461059681190818e-07, 'gt': 1}],
#  [{'label': 1, 'score': 0.9097895622253418, 'gt': 1},
#   {'label': 0, 'score': 0.09021048992872238, 'gt': 1}],
#  [{'label': 0, 'score': 0.6710249781608582, 'gt': 0},
#   {'label': 1, 'score': 0.3289750814437866, 'gt': 0}],
#  [{'label': 1, 'score': 0.5231963992118835, 'gt': 1},
#   {'label': 0, 'score': 0.47680357098579407, 'gt': 1}],
#  [{'label': 1, 'score': 0.9995458722114563, 'gt': 1},
#   {'label': 0, 'score': 0.00045414644409902394, 'gt': 1}],
#  [{'label': 0, 'score': 0.7582883238792419, 'gt': 1},
#   {'label': 1, 'score': 0.24171166121959686, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.4932264313927135e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.875592052936554, 'gt': 1},
#   {'label': 0, 'score': 0.12440799176692963, 'gt': 1}],
#  [{'label': 1, 'score': 0.8945279717445374, 'gt': 1},
#   {'label': 0, 'score': 0.10547204315662384, 'gt': 1}],
#  [{'label': 1, 'score': 0.9739593863487244, 'gt': 1},
#   {'label': 0, 'score': 0.0260405745357275, 'gt': 1}],
#  [{'label': 0, 'score': 0.9964268803596497, 'gt': 1},
#   {'label': 1, 'score': 0.0035730781964957714, 'gt': 1}],
#  [{'label': 0, 'score': 0.9758157730102539, 'gt': 1},
#   {'label': 1, 'score': 0.02418428286910057, 'gt': 1}],
#  [{'label': 1, 'score': 0.9759947061538696, 'gt': 0},
#   {'label': 0, 'score': 0.024005332961678505, 'gt': 0}],
#  [{'label': 1, 'score': 0.9953451752662659, 'gt': 0},
#   {'label': 0, 'score': 0.004654844757169485, 'gt': 0}],
#  [{'label': 0, 'score': 0.985154926776886, 'gt': 0},
#   {'label': 1, 'score': 0.01484509464353323, 'gt': 0}],
#  [{'label': 1, 'score': 0.9901644587516785, 'gt': 1},
#   {'label': 0, 'score': 0.009835529141128063, 'gt': 1}],
#  [{'label': 1, 'score': 0.992402195930481, 'gt': 1},
#   {'label': 0, 'score': 0.007597767747938633, 'gt': 1}],
#  [{'label': 0, 'score': 0.783926248550415, 'gt': 1},
#   {'label': 1, 'score': 0.21607372164726257, 'gt': 1}],
#  [{'label': 1, 'score': 0.9752487540245056, 'gt': 1},
#   {'label': 0, 'score': 0.02475123666226864, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 0},
#   {'label': 0, 'score': 1.8481620400745413e-10, 'gt': 0}],
#  [{'label': 0, 'score': 0.6082008481025696, 'gt': 1},
#   {'label': 1, 'score': 0.39179909229278564, 'gt': 1}],
#  [{'label': 1, 'score': 0.9989463686943054, 'gt': 1},
#   {'label': 0, 'score': 0.001053709420375526, 'gt': 1}],
#  [{'label': 0, 'score': 0.9866646528244019, 'gt': 1},
#   {'label': 1, 'score': 0.013335319235920906, 'gt': 1}],
#  [{'label': 0, 'score': 0.6483392715454102, 'gt': 0},
#   {'label': 1, 'score': 0.35166075825691223, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999513626098633, 'gt': 0},
#   {'label': 0, 'score': 4.8679663450457156e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999853372573853, 'gt': 0},
#   {'label': 0, 'score': 1.4622386515839025e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999850988388062, 'gt': 0},
#   {'label': 0, 'score': 1.4859537259326316e-05, 'gt': 0}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 5.621367815678013e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.9670307636260986, 'gt': 1},
#   {'label': 0, 'score': 0.03296922147274017, 'gt': 1}],
#  [{'label': 1, 'score': 0.9935411214828491, 'gt': 1},
#   {'label': 0, 'score': 0.006458833813667297, 'gt': 1}],
#  [{'label': 1, 'score': 0.9942883253097534, 'gt': 1},
#   {'label': 0, 'score': 0.005711615551263094, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997642636299133, 'gt': 1},
#   {'label': 0, 'score': 0.00023571292695123702, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999970197677612, 'gt': 1},
#   {'label': 0, 'score': 2.997172487084754e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.996997594833374, 'gt': 1},
#   {'label': 0, 'score': 0.003002377925440669, 'gt': 1}],
#  [{'label': 1, 'score': 0.9994089603424072, 'gt': 1},
#   {'label': 0, 'score': 0.0005910922773182392, 'gt': 1}],
#  [{'label': 1, 'score': 0.9974875450134277, 'gt': 1},
#   {'label': 0, 'score': 0.0025123856030404568, 'gt': 1}],
#  [{'label': 0, 'score': 0.8045135140419006, 'gt': 1},
#   {'label': 1, 'score': 0.19548650085926056, 'gt': 1}],
#  [{'label': 1, 'score': 0.9944429993629456, 'gt': 1},
#   {'label': 0, 'score': 0.005556953139603138, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999998807907104, 'gt': 1},
#   {'label': 0, 'score': 1.7591520418136497e-07, 'gt': 1}],
#  [{'label': 1, 'score': 0.9826792478561401, 'gt': 1},
#   {'label': 0, 'score': 0.017320698127150536, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997976422309875, 'gt': 1},
#   {'label': 0, 'score': 0.00020243051403667778, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.368783753008529e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9182074069976807, 'gt': 0},
#   {'label': 0, 'score': 0.08179262280464172, 'gt': 0}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 3.069079568263078e-08, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.6742739139541385e-10, 'gt': 1}],
#  [{'label': 1, 'score': 0.996781587600708, 'gt': 1},
#   {'label': 0, 'score': 0.003218426601961255, 'gt': 1}],
#  [{'label': 0, 'score': 0.8437705039978027, 'gt': 1},
#   {'label': 1, 'score': 0.1562294363975525, 'gt': 1}],
#  [{'label': 1, 'score': 0.6286274194717407, 'gt': 1},
#   {'label': 0, 'score': 0.3713725805282593, 'gt': 1}],
#  [{'label': 1, 'score': 0.9817503690719604, 'gt': 1},
#   {'label': 0, 'score': 0.018249694257974625, 'gt': 1}],
#  [{'label': 1, 'score': 0.997471809387207, 'gt': 1},
#   {'label': 0, 'score': 0.0025282197166234255, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999294281005859, 'gt': 1},
#   {'label': 0, 'score': 7.054946763673797e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999971389770508, 'gt': 1},
#   {'label': 0, 'score': 2.8891781767015345e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9418141841888428, 'gt': 1},
#   {'label': 0, 'score': 0.05818586051464081, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998261332511902, 'gt': 1},
#   {'label': 0, 'score': 0.00017384107923135161, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998815059661865, 'gt': 1},
#   {'label': 0, 'score': 0.00011852174066007137, 'gt': 1}],
#  [{'label': 1, 'score': 0.9982321858406067, 'gt': 0},
#   {'label': 0, 'score': 0.0017678862204775214, 'gt': 0}],
#  [{'label': 1, 'score': 0.9894813299179077, 'gt': 0},
#   {'label': 0, 'score': 0.010518709197640419, 'gt': 0}],
#  [{'label': 1, 'score': 0.9997403025627136, 'gt': 1},
#   {'label': 0, 'score': 0.00025964895030483603, 'gt': 1}],
#  [{'label': 1, 'score': 0.9636825323104858, 'gt': 1},
#   {'label': 0, 'score': 0.03631747514009476, 'gt': 1}],
#  [{'label': 1, 'score': 0.996493399143219, 'gt': 1},
#   {'label': 0, 'score': 0.0035065910778939724, 'gt': 1}],
#  [{'label': 1, 'score': 0.9055289030075073, 'gt': 1},
#   {'label': 0, 'score': 0.0944710448384285, 'gt': 1}],
#  [{'label': 1, 'score': 0.9995527863502502, 'gt': 1},
#   {'label': 0, 'score': 0.0004471999127417803, 'gt': 1}],
#  [{'label': 1, 'score': 0.827032744884491, 'gt': 1},
#   {'label': 0, 'score': 0.17296725511550903, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999914169311523, 'gt': 1},
#   {'label': 0, 'score': 8.525139492121525e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9844410419464111, 'gt': 1},
#   {'label': 0, 'score': 0.015559008345007896, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999598264694214, 'gt': 1},
#   {'label': 0, 'score': 4.015001832158305e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.9915773868560791, 'gt': 1},
#   {'label': 1, 'score': 0.008422601968050003, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998575448989868, 'gt': 1},
#   {'label': 0, 'score': 0.000142466087709181, 'gt': 1}],
#  [{'label': 1, 'score': 0.9994634985923767, 'gt': 1},
#   {'label': 0, 'score': 0.0005364928510971367, 'gt': 1}],
#  [{'label': 1, 'score': 0.9980880618095398, 'gt': 1},
#   {'label': 0, 'score': 0.0019118564669042826, 'gt': 1}],
#  [{'label': 1, 'score': 0.999951958656311, 'gt': 1},
#   {'label': 0, 'score': 4.8016572691267356e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.995685338973999, 'gt': 1},
#   {'label': 0, 'score': 0.004314659163355827, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998902082443237, 'gt': 1},
#   {'label': 0, 'score': 0.00010979361104546115, 'gt': 1}],
#  [{'label': 1, 'score': 0.9935291409492493, 'gt': 1},
#   {'label': 0, 'score': 0.006470886059105396, 'gt': 1}],
#  [{'label': 1, 'score': 0.9995817542076111, 'gt': 1},
#   {'label': 0, 'score': 0.00041821575723588467, 'gt': 1}],
#  [{'label': 1, 'score': 0.9177229404449463, 'gt': 1},
#   {'label': 0, 'score': 0.0822770893573761, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999955892562866, 'gt': 1},
#   {'label': 0, 'score': 4.404757419251837e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9991399049758911, 'gt': 1},
#   {'label': 0, 'score': 0.0008600876899436116, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998925924301147, 'gt': 1},
#   {'label': 0, 'score': 0.00010742298036348075, 'gt': 1}],
#  [{'label': 1, 'score': 0.7890539765357971, 'gt': 1},
#   {'label': 0, 'score': 0.21094602346420288, 'gt': 1}],
#  [{'label': 1, 'score': 0.9834149479866028, 'gt': 0},
#   {'label': 0, 'score': 0.01658502407371998, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999055862426758, 'gt': 0},
#   {'label': 0, 'score': 9.438103006687015e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999613761901855, 'gt': 0},
#   {'label': 0, 'score': 3.8670692447340116e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9899331331253052, 'gt': 1},
#   {'label': 0, 'score': 0.010066840797662735, 'gt': 1}],
#  [{'label': 1, 'score': 0.9978669881820679, 'gt': 1},
#   {'label': 0, 'score': 0.002132965950295329, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997180104255676, 'gt': 1},
#   {'label': 0, 'score': 0.00028199373628012836, 'gt': 1}],
#  [{'label': 0, 'score': 0.7164420485496521, 'gt': 1},
#   {'label': 1, 'score': 0.2835579514503479, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999992847442627, 'gt': 1},
#   {'label': 0, 'score': 7.256723506543494e-07, 'gt': 1}],
#  [{'label': 0, 'score': 0.5082184672355652, 'gt': 1},
#   {'label': 1, 'score': 0.4917815923690796, 'gt': 1}],
#  [{'label': 0, 'score': 0.704399049282074, 'gt': 0},
#   {'label': 1, 'score': 0.29560092091560364, 'gt': 0}],
#  [{'label': 1, 'score': 0.9996719360351562, 'gt': 0},
#   {'label': 0, 'score': 0.00032807563547976315, 'gt': 0}],
#  [{'label': 1, 'score': 0.9988358616828918, 'gt': 1},
#   {'label': 0, 'score': 0.0011642028111964464, 'gt': 1}],
#  [{'label': 1, 'score': 0.986286461353302, 'gt': 0},
#   {'label': 0, 'score': 0.01371357124298811, 'gt': 0}],
#  [{'label': 1, 'score': 0.8165915608406067, 'gt': 0},
#   {'label': 0, 'score': 0.1834084689617157, 'gt': 0}],
#  [{'label': 0, 'score': 0.9558629989624023, 'gt': 0},
#   {'label': 1, 'score': 0.044136933982372284, 'gt': 0}],
#  [{'label': 1, 'score': 0.7626648545265198, 'gt': 0},
#   {'label': 0, 'score': 0.23733514547348022, 'gt': 0}],
#  [{'label': 1, 'score': 0.9917579293251038, 'gt': 1},
#   {'label': 0, 'score': 0.008242066949605942, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999998807907104, 'gt': 1},
#   {'label': 0, 'score': 8.195176093295231e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999961853027344, 'gt': 1},
#   {'label': 0, 'score': 3.833497430605348e-06, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.851854847245704e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999983310699463, 'gt': 0},
#   {'label': 0, 'score': 1.6646707763356972e-06, 'gt': 0}],
#  [{'label': 1, 'score': 0.9611426591873169, 'gt': 0},
#   {'label': 0, 'score': 0.038857363164424896, 'gt': 0}],
#  [{'label': 1, 'score': 0.8481799960136414, 'gt': 0},
#   {'label': 0, 'score': 0.15181997418403625, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999169111251831, 'gt': 0},
#   {'label': 0, 'score': 8.308231190312654e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9874681234359741, 'gt': 1},
#   {'label': 0, 'score': 0.01253189705312252, 'gt': 1}],
#  [{'label': 1, 'score': 0.9993605017662048, 'gt': 1},
#   {'label': 0, 'score': 0.0006395283271558583, 'gt': 1}],
#  [{'label': 1, 'score': 0.999716579914093, 'gt': 0},
#   {'label': 0, 'score': 0.000283431465504691, 'gt': 0}],
#  [{'label': 1, 'score': 0.7653512358665466, 'gt': 1},
#   {'label': 0, 'score': 0.2346487194299698, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 7.299402243566091e-16, 'gt': 1}],
#  [{'label': 1, 'score': 0.9990410208702087, 'gt': 1},
#   {'label': 0, 'score': 0.0009589974069967866, 'gt': 1}],
#  [{'label': 1, 'score': 0.8079362511634827, 'gt': 1},
#   {'label': 0, 'score': 0.19206379354000092, 'gt': 1}],
#  [{'label': 1, 'score': 0.9028884172439575, 'gt': 1},
#   {'label': 0, 'score': 0.09711162745952606, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999988079071045, 'gt': 1},
#   {'label': 0, 'score': 1.1763248721763375e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997511506080627, 'gt': 1},
#   {'label': 0, 'score': 0.0002488680474925786, 'gt': 1}],
#  [{'label': 1, 'score': 0.999998927116394, 'gt': 1},
#   {'label': 0, 'score': 1.057516328728525e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9994634985923767, 'gt': 1},
#   {'label': 0, 'score': 0.0005364626995287836, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 5.518016710226448e-09, 'gt': 1}],
#  [{'label': 0, 'score': 0.9832214117050171, 'gt': 0},
#   {'label': 1, 'score': 0.016778573393821716, 'gt': 0}],
#  [{'label': 1, 'score': 0.998375415802002, 'gt': 0},
#   {'label': 0, 'score': 0.0016245524166151881, 'gt': 0}],
#  [{'label': 1, 'score': 0.9670116901397705, 'gt': 0},
#   {'label': 0, 'score': 0.03298827260732651, 'gt': 0}],
#  [{'label': 1, 'score': 0.9787868857383728, 'gt': 1},
#   {'label': 0, 'score': 0.021213117986917496, 'gt': 1}],
#  [{'label': 1, 'score': 0.9996165037155151, 'gt': 1},
#   {'label': 0, 'score': 0.00038344471249729395, 'gt': 1}],
#  [{'label': 1, 'score': 0.9992436170578003, 'gt': 1},
#   {'label': 0, 'score': 0.000756371533498168, 'gt': 1}],
#  [{'label': 1, 'score': 0.9994840621948242, 'gt': 1},
#   {'label': 0, 'score': 0.0005159612046554685, 'gt': 1}],
#  [{'label': 1, 'score': 0.9815667867660522, 'gt': 1},
#   {'label': 0, 'score': 0.01843317598104477, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 4.979999523868628e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.9291620850563049, 'gt': 1},
#   {'label': 0, 'score': 0.07083798199892044, 'gt': 1}],
#  [{'label': 1, 'score': 0.711061954498291, 'gt': 1},
#   {'label': 0, 'score': 0.28893810510635376, 'gt': 1}],
#  [{'label': 0, 'score': 0.9728992581367493, 'gt': 1},
#   {'label': 1, 'score': 0.027100741863250732, 'gt': 1}],
#  [{'label': 1, 'score': 0.9675452709197998, 'gt': 1},
#   {'label': 0, 'score': 0.032454751431941986, 'gt': 1}],
#  [{'label': 1, 'score': 0.999951958656311, 'gt': 1},
#   {'label': 0, 'score': 4.8002377297962084e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.8769440054893494, 'gt': 0},
#   {'label': 1, 'score': 0.12305594980716705, 'gt': 0}],
#  [{'label': 0, 'score': 0.9978843331336975, 'gt': 0},
#   {'label': 1, 'score': 0.002115654991939664, 'gt': 0}],
#  [{'label': 0, 'score': 0.9350932240486145, 'gt': 0},
#   {'label': 1, 'score': 0.0649067834019661, 'gt': 0}],
#  [{'label': 0, 'score': 0.7805863618850708, 'gt': 0},
#   {'label': 1, 'score': 0.219413623213768, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999529123306274, 'gt': 1},
#   {'label': 0, 'score': 4.705493847723119e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999783039093018, 'gt': 1},
#   {'label': 0, 'score': 2.1741518139606342e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.5946310758590698, 'gt': 1},
#   {'label': 0, 'score': 0.4053688943386078, 'gt': 1}],
#  [{'label': 1, 'score': 0.998578667640686, 'gt': 1},
#   {'label': 0, 'score': 0.0014213481917977333, 'gt': 1}],
#  [{'label': 1, 'score': 0.9868521094322205, 'gt': 1},
#   {'label': 0, 'score': 0.013147935271263123, 'gt': 1}],
#  [{'label': 1, 'score': 0.9989620447158813, 'gt': 1},
#   {'label': 0, 'score': 0.0010380020830780268, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999680519104004, 'gt': 1},
#   {'label': 0, 'score': 3.194263990735635e-05, 'gt': 1}],
#  [{'label': 0, 'score': 0.984917938709259, 'gt': 1},
#   {'label': 1, 'score': 0.015082031488418579, 'gt': 1}],
#  [{'label': 0, 'score': 0.9874575734138489, 'gt': 1},
#   {'label': 1, 'score': 0.012542427517473698, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999805688858032, 'gt': 1},
#   {'label': 0, 'score': 1.9439470634097233e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.959567129611969, 'gt': 1},
#   {'label': 0, 'score': 0.040432874113321304, 'gt': 1}],
#  [{'label': 1, 'score': 0.591483473777771, 'gt': 1},
#   {'label': 0, 'score': 0.4085164964199066, 'gt': 1}],
#  [{'label': 1, 'score': 0.9830832481384277, 'gt': 1},
#   {'label': 0, 'score': 0.016916761174798012, 'gt': 1}],
#  [{'label': 0, 'score': 0.5141932368278503, 'gt': 1},
#   {'label': 1, 'score': 0.48580679297447205, 'gt': 1}],
#  [{'label': 1, 'score': 0.9306938648223877, 'gt': 1},
#   {'label': 0, 'score': 0.0693061575293541, 'gt': 1}],
#  [{'label': 1, 'score': 0.7414278388023376, 'gt': 0},
#   {'label': 0, 'score': 0.25857213139533997, 'gt': 0}],
#  [{'label': 1, 'score': 1.0, 'gt': 0},
#   {'label': 0, 'score': 1.5451077510217413e-21, 'gt': 0}],
#  [{'label': 1, 'score': 1.0, 'gt': 0},
#   {'label': 0, 'score': 6.853869916056965e-09, 'gt': 0}],
#  [{'label': 0, 'score': 0.9773563146591187, 'gt': 0},
#   {'label': 1, 'score': 0.022643743082880974, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999774694442749, 'gt': 1},
#   {'label': 0, 'score': 2.251244404760655e-05, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 7.132319179703472e-10, 'gt': 1}],
#  [{'label': 1, 'score': 0.9997938275337219, 'gt': 1},
#   {'label': 0, 'score': 0.0002062239800579846, 'gt': 1}],
#  [{'label': 1, 'score': 0.9998267292976379, 'gt': 1},
#   {'label': 0, 'score': 0.0001733484969008714, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999949932098389, 'gt': 1},
#   {'label': 0, 'score': 5.036700713390019e-06, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999755620956421, 'gt': 0},
#   {'label': 0, 'score': 2.4412684069829993e-05, 'gt': 0}],
#  [{'label': 1, 'score': 0.9509488344192505, 'gt': 0},
#   {'label': 0, 'score': 0.04905111715197563, 'gt': 0}],
#  [{'label': 0, 'score': 0.999305009841919, 'gt': 0},
#   {'label': 1, 'score': 0.0006949456292204559, 'gt': 0}],
#  [{'label': 1, 'score': 0.9490928053855896, 'gt': 0},
#   {'label': 0, 'score': 0.05090722069144249, 'gt': 0}],
#  [{'label': 0, 'score': 0.8656885027885437, 'gt': 1},
#   {'label': 1, 'score': 0.1343114823102951, 'gt': 1}],
#  [{'label': 0, 'score': 0.9729087352752686, 'gt': 0},
#   {'label': 1, 'score': 0.027091262862086296, 'gt': 0}],
#  [{'label': 1, 'score': 0.99996018409729, 'gt': 1},
#   {'label': 0, 'score': 3.980818291893229e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9912095069885254, 'gt': 1},
#   {'label': 0, 'score': 0.008790545165538788, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.0542613448905058e-09, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 0},
#   {'label': 0, 'score': 2.4343982829577726e-08, 'gt': 0}],
#  [{'label': 1, 'score': 0.9999946355819702, 'gt': 0},
#   {'label': 0, 'score': 5.369684458855772e-06, 'gt': 0}],
#  [{'label': 1, 'score': 0.9166173338890076, 'gt': 0},
#   {'label': 0, 'score': 0.08338262140750885, 'gt': 0}],
#  [{'label': 1, 'score': 0.9979667663574219, 'gt': 1},
#   {'label': 0, 'score': 0.0020332508720457554, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.8441557170234546e-09, 'gt': 1}],
#  [{'label': 1, 'score': 0.9856007695198059, 'gt': 1},
#   {'label': 0, 'score': 0.014399203471839428, 'gt': 1}],
#  [{'label': 1, 'score': 0.5880643725395203, 'gt': 1},
#   {'label': 0, 'score': 0.4119356572628021, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.5178634737988972e-10, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 5.5550608557553005e-09, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 3.921469895904134e-15, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.623111469176413e-14, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 1.5980834433548807e-08, 'gt': 1}],
#  [{'label': 1, 'score': 1.0, 'gt': 1},
#   {'label': 0, 'score': 9.857084329812823e-27, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999148845672607, 'gt': 1},
#   {'label': 0, 'score': 8.510884799761698e-05, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999998807907104, 'gt': 1},
#   {'label': 0, 'score': 8.329457301670118e-08, 'gt': 1}],
#  [{'label': 1, 'score': 0.8977357745170593, 'gt': 1},
#   {'label': 0, 'score': 0.10226425528526306, 'gt': 1}],
#  [{'label': 1, 'score': 0.9857520461082458, 'gt': 1},
#   {'label': 0, 'score': 0.01424797996878624, 'gt': 1}],
#  [{'label': 1, 'score': 0.9321041107177734, 'gt': 1},
#   {'label': 0, 'score': 0.06789591163396835, 'gt': 1}],
#  [{'label': 1, 'score': 0.9999982118606567, 'gt': 1},
#   {'label': 0, 'score': 1.8241970565213705e-06, 'gt': 1}]]

# %%
gt = [
    res[0]['gt']
    for res in results['results']
]

# %%
preds = [
    res[np.argmax([pred['score'] for pred in res])]['label']
    for res in results['results']
]

# %%
def compute_prf1(preds, gts, class_name):
    tp = len([1 for pred, gt in zip(preds, gts) if gt == class_name and pred == gt])
    fp = len([1 for pred, gt in zip(preds, gts) if pred == class_name and pred != gt])
    fn = len([1 for pred, gt in zip(preds, gts) if gt == class_name and pred != gt])
    
    pre = tp / (tp + fp) if tp + fp > 0 else 0
    rec = tp / (tp + fn)
    f1 = 2 * pre * rec  / (pre + rec) if pre + rec > 0  else 0
    
    return pre, rec, f1, tp, fp, fn

# %%
for class_name in [1]:
    print(class_name, compute_prf1(preds, gt, class_name))
# Out:
# 1 (0.7874015748031497, 0.8333333333333334, 0.8097165991902834, 200, 54, 40)
