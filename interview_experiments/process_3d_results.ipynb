# %%
import json
import pickle
import numpy as np

# %%
with open('results/test.json', 'r') as f:
    results = json.load(f)

# %%
results.keys()
# Out:
# dict_keys(['results'])

# %%
len(results['results'])
# Out:
# 230

# %%
results['results']
# Out:
# [[{'label': 0, 'score': 1.0, 'gt': 1}, {'label': 1, 'score': 0.0, 'gt': 1}],
#  [{'label': 0, 'score': 0.9999998807907104, 'gt': 1},
#   {'label': 1, 'score': 1.1471915684069245e-07, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 1}, {'label': 1, 'score': 0.0, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 1},
#   {'label': 1, 'score': 5.40295819586792e-23, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.2022803631581165e-21, 'gt': 0}],
#  [{'label': 0, 'score': 0.9956820011138916, 'gt': 0},
#   {'label': 1, 'score': 0.004317937884479761, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9999939203262329, 'gt': 0},
#   {'label': 1, 'score': 6.072280484659132e-06, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 1}, {'label': 1, 'score': 0.0, 'gt': 1}],
#  [{'label': 0, 'score': 0.9847404360771179, 'gt': 1},
#   {'label': 1, 'score': 0.01525956578552723, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 8.975870069722555e-34, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.3159920095487289e-20, 'gt': 0}],
#  [{'label': 0, 'score': 0.9874621033668518, 'gt': 0},
#   {'label': 1, 'score': 0.012537929229438305, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 1}, {'label': 1, 'score': 0.0, 'gt': 1}],
#  [{'label': 0, 'score': 0.9867160320281982, 'gt': 1},
#   {'label': 1, 'score': 0.013283958658576012, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9350607991218567, 'gt': 0},
#   {'label': 1, 'score': 0.06493920087814331, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 1},
#   {'label': 1, 'score': 2.8499748297284562e-40, 'gt': 1}],
#  [{'label': 0, 'score': 0.9856582283973694, 'gt': 1},
#   {'label': 1, 'score': 0.014341720379889011, 'gt': 1}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9417561292648315, 'gt': 0},
#   {'label': 1, 'score': 0.058243826031684875, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9765850901603699, 'gt': 0},
#   {'label': 1, 'score': 0.023414889350533485, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 2.4074250148183214e-14, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 2.384847714394057e-33, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9983924031257629, 'gt': 0},
#   {'label': 1, 'score': 0.001607535406947136, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 8.458864719784742e-09, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.999195396900177, 'gt': 0},
#   {'label': 1, 'score': 0.0008046350558288395, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.1990380205644663e-13, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9038312435150146, 'gt': 0},
#   {'label': 1, 'score': 0.09616868942975998, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.881356670024547e-21, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9738113880157471, 'gt': 0},
#   {'label': 1, 'score': 0.026188639923930168, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 3.3336599211479573e-23, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.898780438637092e-39, 'gt': 0}],
#  [{'label': 0, 'score': 0.9801152944564819, 'gt': 0},
#   {'label': 1, 'score': 0.019884712994098663, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9338468313217163, 'gt': 0},
#   {'label': 1, 'score': 0.06615319103002548, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 2.802596928649634e-45, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9999980926513672, 'gt': 0},
#   {'label': 1, 'score': 1.8747690546661033e-06, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9999995231628418, 'gt': 0},
#   {'label': 1, 'score': 4.86765713958448e-07, 'gt': 0}],
#  [{'label': 0, 'score': 0.9663625955581665, 'gt': 0},
#   {'label': 1, 'score': 0.03363747149705887, 'gt': 0}],
#  [{'label': 0, 'score': 0.9368764162063599, 'gt': 0},
#   {'label': 1, 'score': 0.06312359124422073, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 1.9548683959711462e-29, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 8.878328200596813e-29, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0},
#   {'label': 1, 'score': 8.462485947451429e-15, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 0.9998455047607422, 'gt': 0},
#   {'label': 1, 'score': 0.00015450622595380992, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}],
#  [{'label': 0, 'score': 1.0, 'gt': 0}, {'label': 1, 'score': 0.0, 'gt': 0}]]

# %%
gt = [
    res[0]['gt']
    for res in results['results']
]

# %%
preds = [
    res[np.argmax([pred['score'] for pred in res])]['label']
    for res in results['results']
]

# %%
def compute_prf1(preds, gts, class_name):
    tp = len([1 for pred, gt in zip(preds, gts) if gt == class_name and pred == gt])
    fp = len([1 for pred, gt in zip(preds, gts) if pred == class_name and pred != gt])
    fn = len([1 for pred, gt in zip(preds, gts) if gt == class_name and pred != gt])
    
    pre = tp / (tp + fp) if tp + fp > 0 else 0
    rec = tp / (tp + fn)
    f1 = 2 * pre * rec  / (pre + rec) if pre + rec > 0  else 0
    
    return pre, rec, f1, tp, fp, fn

# %%
for class_name in [1]:
    print(class_name, compute_prf1(preds, gt, class_name))
# Out:
# 1 (0, 0.0, 0, 0, 0, 10)
