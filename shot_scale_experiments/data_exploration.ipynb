# %%
import pickle

# %%
with open('shot_scale/shot_scale_labels_and_rekall_accuracy_val_test.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['long_test', 'long_val', 'medium_accuracy_test', 'close_up_val', 'long_accuracy_test', 'close_up_test', 'false_positive_long_val', 'false_positive_close_up_val', 'val_set', 'false_positive_medium_test', 'close_up_accuracy_test', 'close_up_accuracy_val', 'medium_accuracy_val', 'long_accuracy_val', 'medium_test', 'false_positive_close_up_test', 'false_positive_long_test', 'medium_val', 'test_set', 'false_positive_medium_val'])

# %%
data['long_test']
# Out:
# [((147, 12295, 12501), 1),
#  ((517, 81553, 81652), 1),
#  ((543, 158953, 159020), 1),
#  ((271, 9914, 9976), 1),
#  ((484, 6103, 6126), 1),
#  ((97, 117601, 117644), 1),
#  ((628, 84447, 84586), 1),
#  ((453, 85295, 85444), 1),
#  ((138, 143584, 143616), 1),
#  ((332, 112026, 112061), 1),
#  ((80, 113395, 113453), 1),
#  ((216, 213128, 213275), 1),
#  ((232, 93714, 93908), 1),
#  ((18, 111391, 111406), 1),
#  ((615, 114707, 114723), 1),
#  ((157, 71739, 71761), 1),
#  ((95, 45316, 45438), 1),
#  ((372, 123727, 123847), 1),
#  ((352, 6025, 6072), 1),
#  ((88, 46212, 46225), 1),
#  ((196, 105427, 105620), 1),
#  ((420, 157143, 157316), 1),
#  ((221, 8248, 8550), 1),
#  ((139, 86066, 86455), 1),
#  ((405, 204127, 204238), 1),
#  ((606, 109753, 109806), 1),
#  ((218, 122083, 122656), 1),
#  ((486, 19728, 19846), 1),
#  ((220, 83280, 83317), 1),
#  ((559, 108809, 108891), 1),
#  ((388, 169913, 170272), 1),
#  ((79, 124281, 124415), 1),
#  ((532, 37437, 37753), 1),
# ...
